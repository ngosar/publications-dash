# %%
# requires installing Biopython (using pip) to be able to ping PubMed
#MEDLINE data element fields: https://www.nlm.nih.gov/bsd/mms/medlineelements.html

# %%
from Bio import Entrez #to tap into PubMed database
import re #for text searching
import pandas as pd #to export PMID's or PubMed Queries if needed

# %%
Entrez.email = "sarah.ngo@ucsf.edu" #to let NLM know who I am

# %%
def get_links_term(term):
    links = Entrez.esearch(db="pubmed", retmax = 1000, term=term)
    record = Entrez.read(links)
    link_list = record['IdList']
    
    return link_list
    

def get_medline(pubmed_list):
    handle = Entrez.efetch(db='pubmed',id=pubmed_list, retmode='text', rettype='medline')
    return handle.read()


def get_mesh_terms(link_list):
    record = Entrez.efetch(db="pubmed", retmax = 1000, term=term)
    

query = input("what do you want to search for?")


#links_term = get_links_term(query)
pubmed_record = get_links_term(query)

pubmed_dict = {}
for record in pubmed_record:
    medline_record = get_medline(record)

    #cleaning the medline record
    refined_text = medline_record.split('\n')

    # using re + search() to search within string for substring  
    mesh = "MH "
    mesh_terms = [line.replace(mesh,'') for line in refined_text if re.search(mesh, line)] 
    pubmed_dict[record] = mesh_terms
# Out:
# what do you want to search for?aging[mh] san francisco[ad] geriatrics[mh]

# %%
pubmed_dict
# Out:
# {'31272896': [' - Aging',
#   ' - Biomedical Research',
#   ' - Congresses as Topic',
#   ' - Geriatrics/education/*organization & administration',
#   ' - Humans',
#   ' - Medical Oncology/education/*organization & administration',
#   ' - Neoplasms/*therapy',
#   ' - Societies, Medical'],
#  '30693953': [' - *Aging/physiology/psychology',
#   ' - *Geriatrics/methods/organization & administration',
#   ' - Humans',
#   ' - Multiple Chronic Conditions/*prevention & control',
#   ' - *National Institute on Aging (U.S.)',
#   ' - Research',
#   ' - Societies, Medical',
#   ' - United States'],
#  '30604862': [' - *Aging',
#   ' - Curriculum',
#   ' - Educational Status',
#   ' - *Geriatrics/education/methods',
#   ' - Humans',
#   ' - *Leadership',
#   ' - Models, Educational',
#   ' - Program Development',
#   ' - Program Evaluation',
#   ' - Societies, Medical',
#   ' - Staff Development/*methods',
#   ' - United States'],
#  '30604860': [' - *Aging',
#   ' - Curriculum',
#   ' - Educational Status',
#   ' - *Geriatrics/education/methods',
#   ' - Health Services for the Aged/*standards',
#   ' - Humans',
#   ' - *Leadership',
#   ' - Models, Organizational',
#   ' - Program Development',
#   ' - Program Evaluation',
#   ' - Quality Improvement/organization & administration',
#   ' - *Staff Development/methods/organization & administration',
#   ' - United States'],
#  '30248173': [' - Aged',
#   ' - Aging/physiology',
#   ' - Brain',
#   ' - Cognitive Dysfunction/*physiopathology',
#   ' - *Congresses as Topic',
#   ' - Deaf-Blind Disorders/*physiopathology',
#   ' - Dementia',
#   ' - Female',
#   ' - *Geriatrics',
#   ' - Humans',
#   ' - Male',
#   ' - *National Institute on Aging (U.S.)',
#   ' - Societies, Medical/*organization & administration',
#   ' - United States'],
#  '30124872': [' - Aging',
#   ' - *Geriatricians',
#   ' - *Geriatrics',
#   ' - *Health Policy',
#   ' - Humans',
#   ' - Public Health',
#   ' - Research',
#   ' - Residence Characteristics'],
#  '29759912': [' - Aged',
#   ' - Aging/*physiology',
#   ' - Clinical Trials as Topic',
#   ' - Geriatrics/*education',
#   ' - *Hematologic Diseases/genetics/therapy',
#   ' - Humans'],
#  '29508391': [' - Aging/*psychology',
#   ' - Choice Behavior',
#   ' - *Death',
#   ' - *Geriatrics',
#   ' - Humans',
#   ' - Palliative Care/*psychology'],
#  '26419976': [' - Aged',
#   ' - Aging/pathology/*physiology',
#   ' - *Demography',
#   ' - Female',
#   ' - Geriatrics/*trends',
#   ' - Health Promotion',
#   ' - Health Services Needs and Demand',
#   ' - Health Services for the Aged',
#   ' - Humans',
#   ' - Life Expectancy',
#   ' - Longevity',
#   ' - Male',
#   ' - Quality of Life',
#   ' - Translational Medical Research'],
#  '25875498': [' - Aging/physiology/*psychology',
#   ' - Cognition/*physiology',
#   ' - Geriatrics',
#   ' - Humans',
#   ' - Memory/physiology',
#   ' - National Academies of Science, Engineering, and Medicine, U.S., Health and',
#   ' - United States'],
#  '24814830': [' - Adaptation, Psychological',
#   ' - Aged',
#   ' - Aging/*psychology',
#   ' - Female',
#   ' - *Geriatrics',
#   ' - *Health Status',
#   ' - Humans',
#   ' - Male',
#   ' - Models, Theoretical',
#   ' - *Quality of Life',
#   ' - Social Support'],
#  '24611718': [' - Aged',
#   ' - *Aging',
#   ' - California/epidemiology',
#   ' - Cognition Disorders/epidemiology/*therapy',
#   ' - Female',
#   ' - Geriatrics/*legislation & jurisprudence',
#   ' - *Health Knowledge, Attitudes, Practice',
#   ' - Health Services for the Aged/organization & administration',
#   ' - Humans',
#   ' - Incidence',
#   ' - Male',
#   ' - Prisoners/*legislation & jurisprudence',
#   ' - Social Work/*legislation & jurisprudence',
#   ' - United States/epidemiology',
#   ' - Vulnerable Populations/*legislation & jurisprudence/statistics & numerical data',
#   ' - Workforce'],
#  '23777331': [' - Aged',
#   ' - Aging',
#   ' - Chronic Disease/*epidemiology',
#   ' - Comorbidity/*trends',
#   ' - Geriatrics/*standards/trends',
#   ' - Global Health/trends',
#   ' - Health Priorities/*standards/trends',
#   ' - Health Services Research/*standards/trends',
#   ' - Humans',
#   ' - Life Expectancy/trends',
#   ' - Palliative Care/*standards/trends',
#   ' - Population Dynamics/trends',
#   ' - Prevalence'],
#  '22939544': [' - Aged',
#   ' - Ageism/*psychology',
#   ' - Aging/*psychology',
#   ' - Alzheimer Disease/psychology',
#   ' - *Attitude of Health Personnel',
#   ' - *Boredom',
#   ' - Clinical Clerkship',
#   ' - Communication',
#   ' - Comorbidity',
#   ' - Curriculum',
#   ' - Family Practice/education',
#   ' - Feedback',
#   ' - *Frustration',
#   ' - Geriatrics/*education',
#   ' - Health Status Indicators',
#   ' - Hospitals, Teaching',
#   ' - Humans',
#   ' - *Internship and Residency',
#   ' - *Physician-Patient Relations',
#   ' - Quality of Health Care',
#   ' - Resuscitation Orders',
#   ' - Socialization',
#   ' - Stereotyping',
#   ' - Students, Medical/*psychology',
#   ' - Teaching Rounds',
#   ' - United States'],
#  '22289063': [' - Accreditation/*methods/standards',
#   ' - Aged',
#   ' - Aging',
#   ' - Educational Status',
#   ' - Geriatrics/*education/standards',
#   ' - Humans',
#   ' - Models, Educational',
#   ' - *Professional Role',
#   ' - *Social Identification',
#   ' - United States',
#   ' - Universities/*standards'],
#  '19251914': [' - Aged',
#   ' - Aging/*genetics/physiology',
#   ' - Biomedical Research/standards/trends',
#   ' - Cellular Senescence/*genetics/physiology',
#   ' - Epigenesis, Genetic/genetics/*physiology',
#   ' - Forecasting',
#   ' - Geriatrics/trends',
#   ' - Humans',
#   ' - Needs Assessment',
#   ' - Sensitivity and Specificity'],
#  '18957725': [' - Aged',
#   ' - Aging/*psychology',
#   ' - Geriatric Assessment/methods',
#   ' - Geriatric Psychiatry/methods/trends',
#   ' - Geriatrics/*methods/trends',
#   ' - Guidelines as Topic',
#   ' - Humans',
#   ' - Neuropsychological Tests/standards',
#   ' - Neuropsychology/*methods/trends',
#   ' - *Physicians'],
#  '16441837': [' - Aging/*drug effects/physiology',
#   ' - Biomarkers/metabolism',
#   ' - *Drug Approval',
#   ' - Geriatrics/trends',
#   ' - Humans',
#   ' - Longevity/*drug effects/physiology',
#   ' - Pharmacology, Clinical/*legislation & jurisprudence/trends'],
#  '15934212': [' - Aging',
#   ' - Geriatrics',
#   ' - History, 20th Century',
#   ' - *Holocaust',
#   ' - Humans',
#   ' - Narration/*history',
#   ' - *Survivors',
#   ' - United States'],
#  '15215267': [' - Aged',
#   ' - Aging/genetics/*physiology',
#   ' - Geriatrics',
#   ' - Humans',
#   ' - Life Expectancy',
#   ' - Longevity/physiology'],
#  '15215261': [' - Aged',
#   ' - Aging/pathology/*physiology',
#   ' - Animals',
#   ' - Geriatrics',
#   ' - Humans',
#   ' - Longevity/physiology'],
#  '11089985': [' - *Aging',
#   ' - Animals',
#   ' - Forecasting',
#   ' - Geriatrics',
#   ' - Health Policy',
#   ' - Humans',
#   ' - Longevity',
#   ' - Research'],
#  '1506117': [' - Aged',
#   ' - Aging/*psychology',
#   ' - Forecasting',
#   ' - Geriatrics/*trends',
#   ' - Humans',
#   ' - *Imagination',
#   ' - *Social Conditions',
#   ' - United States']}

# %%
df = pd.DataFrame.from_dict(pubmed, orient='index')
df = df.transpose()

df = pd.DataFrame(pubmed_dict)
#df.to_csv('pubmedtest.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-79ff8e3ca77b> in <module>
# ----> 1 df = pd.DataFrame(pubmed_dict)
#       2 #df.to_csv('pubmedtest.csv', index=False)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     395             lengths = list(set(raw_lengths))
#     396             if len(lengths) > 1:
# --> 397                 raise ValueError("arrays must all be same length")
#     398
#     399             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
#df.to_csv('pubmedtest.csv', index=False)
