# %% [markdown]
# # PubMed Dashboarding to Identify Research Trends with EntrezPy, Plotly, Dash

# %% [markdown]
# Goal is to pull all publications by a search query, and visualize its NIH compliance, the journals it appears in, and research trends.

# %%
from Bio import Entrez #use this library to access PubMed database and its Medline records
import pandas as pd #to export PMID's or PubMed Queries as needed
from pandas import DataFrame
import plotly.express as px

from jupyter_dash import JupyterDash #use plotly + Dash for building dashboard instead of using default
import dash
import dash_core_components as dcc
import dash_html_components as html

# %%
#to let NLM know who I am
Entrez.email = "sarah.ngo@ucsf.edu"

# %%
#the following formulas are for setting up the dataframe by searching Entrzpy to retrieve the Medline records according to a search query

#this is to return all the PMIDs corresponding to a search term
def get_term_pmids(term):
    links = Entrez.esearch(db="pubmed", retmax = 10000, term=term)
    record = Entrez.read(links)
    link_list = record['IdList']
    return link_list

#this is to check medline record for PMID that the medline records correspond to
def get_medline(pubmed_list):
    handle = Entrez.efetch(db='pubmed',id=pubmed_list, retmode='text', rettype='medline')
    return handle.read()

#this returns all the mesh terms of a set of PMID list
def get_mesh_terms(link_list):
    record = Entrez.efetch(db="pubmed", retmax = 10000, term=term)

# %%
#prompt input for search search, and retrieve results
query = input("what do you want to search for?")
# Out:
# what do you want to search for?((Kotwal A San Francisco AND (2020:2021[pdat])) AND (Kotwal A San Francisco)) AND (Ashwin Kotwal AND (2020:2021[pdat]))

# %%
pmids_list = get_term_pmids(query)
pmids_list
# Out:
# ['33099456', '33048142', '32965024', '32865472', '32803486', '32422084', '32359072', '32356919', '31775021']

# %%
#this is to format the text blob. retrieve medline record and split record by line break so it will not be one big text blob
pmid= get_medline(pmids_list).split('\n')

pubmed_list = []
for element in pmid:
    new_string = element.split('- ')
    pubmed_list.append(new_string)
    #print(new_string) #print to see that it retrieves the right records, and see if it formatted correctly

# %%
pubmed_list
# Out:
# [[''],
#  ['PMID', '33099456'],
#  ['OWN ', 'NLM'],
#  ['STAT', 'MEDLINE'],
#  ['DCOM', '20201030'],
#  ['LR  ', '20201030'],
#  ['IS  ', '1557-9859 (Electronic)'],
#  ['IS  ', '0025-7125 (Linking)'],
#  ['VI  ', '104'],
#  ['IP  ', '6'],
#  ['DP  ', '2020 Nov'],
#  ['TI  ',
#   'Cancer Screening in Older Adults: Individualized Decision-Making and'],
#  ['      Communication Strategies.'],
#  ['PG  ', '989-1006'],
#  ['LID ', 'S0025-7125(20)30080-8 [pii]'],
#  ['LID ', '10.1016/j.mcna.2020.08.002 [doi]'],
#  ['AB  ',
#   'Cancer screening decisions in older adults can be complex due to the unclear'],
#  ['      cancer-specific mortality benefits of screening and several known harms including'],
#  ['      false positives, overdiagnosis, and procedural complications from downstream'],
#  ['      diagnostic interventions. In this review, we provide a framework for'],
#  ['      individualized cancer screening decisions among older adults, involving'],
#  ['      accounting for overall health and life expectancy, individual values, and the'],
#  ['      risks and benefits of specific cancer screening tests. We then discuss strategies'],
#  ['      for effective communication of recommendations during clinical visits that are'],
#  ['      considered more effective, easy to understand, and acceptable by older adults and'],
#  ['      clinicians.'],
#  ['CI  ', 'Copyright (c) 2020 Elsevier Inc. All rights reserved.'],
#  ['FAU ', 'Kotwal, Ashwin A'],
#  ['AU  ', 'Kotwal AA'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, San Francisco, CA, USA; Geriatrics, Palliative, and Extended Care'],
#  ['      Service Line, San Francisco Veterans Affairs Medical Center, San Francisco, CA,'],
#  ['      USA. Electronic address: ashwin.kotwal@ucsf.edu.'],
#  ['FAU ', 'Walter, Louise C'],
#  ['AU  ', 'Walter LC'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, San Francisco, CA, USA; Geriatrics, Palliative, and Extended Care'],
#  ['      Service Line, San Francisco Veterans Affairs Medical Center, San Francisco, CA,'],
#  ['      USA.'],
#  ['LA  ', 'eng'],
#  ['GR  ', 'R03 AG064323/AG/NIA NIH HHS/United States'],
#  ['PT  ', 'Journal Article'],
#  ['PT  ', 'Review'],
#  ['DEP ', '20200916'],
#  ['PL  ', 'United States'],
#  ['TA  ', 'Med Clin North Am'],
#  ['JT  ', 'The Medical clinics of North America'],
#  ['JID ', '2985236R'],
#  ['SB  ', 'AIM'],
#  ['SB  ', 'IM'],
#  ['MH  ', 'Aged'],
#  ['MH  ', 'Aged, 80 and over'],
#  ['MH  ', 'Communication'],
#  ['MH  ', 'Decision Making'],
#  ['MH  ', '*Early Detection of Cancer'],
#  ['MH  ', '*Health Services for the Aged'],
#  ['MH  ', 'Humans'],
#  ['MH  ', 'United States'],
#  ['PMC ', 'PMC7594102'],
#  ['MID ', 'NIHMS1618860'],
#  ['OTO ', 'NOTNLM'],
#  ['OT  ', 'Cancer screening'],
#  ['OT  ', 'Colon cancer'],
#  ['OT  ', 'Lung cancer'],
#  ['OT  ', 'Mammogram'],
#  ['OT  ', 'Older adults'],
#  ['OT  ', 'PSA test'],
#  ['COIS',
#   "Disclosure Dr. Ashwin Kotwal's effort was supported by a GEMSSTAR Award from the "],
#  ['      National Institute on Aging (R03AG064323), the NIA Claude D. Pepper Older'],
#  ['      Americans Independence Center (P30AG044281), and the National Palliative Care'],
#  ["      Research Center Kornfield Scholar's Award. Dr. Louise Walter's effort on this"],
#  ['      project was supported by a K24 Midcareer Mentoring Award for Patient-Oriented'],
#  ['      Research in Aging (K24AG041180) from the National Institute on Aging.'],
#  ['EDAT', '2020/10/26 06:00'],
#  ['MHDA', '2020/10/31 06:00'],
#  ['CRDT', '2020/10/25 20:13'],
#  ['PMCR', '2021/11/01 00:00'],
#  ['PHST', '2021/11/01 00:00 [pmc-release]'],
#  ['PHST', '2020/10/25 20:13 [entrez]'],
#  ['PHST', '2020/10/26 06:00 [pubmed]'],
#  ['PHST', '2020/10/31 06:00 [medline]'],
#  ['AID ', 'S0025-7125(20)30080-8 [pii]'],
#  ['AID ', '10.1016/j.mcna.2020.08.002 [doi]'],
#  ['PST ', 'ppublish'],
#  ['SO  ',
#   'Med Clin North Am. 2020 Nov;104(6):989-1006. doi: 10.1016/j.mcna.2020.08.002.'],
#  ['      Epub 2020 Sep 16.'],
#  [''],
#  ['PMID', '33048142'],
#  ['OWN ', 'NLM'],
#  ['STAT', 'MEDLINE'],
#  ['DCOM', '20201016'],
#  ['LR  ', '20201231'],
#  ['IS  ', '1538-3598 (Electronic)'],
#  ['IS  ', '0098-7484 (Linking)'],
#  ['VI  ', '324'],
#  ['IP  ', '14'],
#  ['DP  ', '2020 Oct 13'],
#  ['TI  ', 'Palliative Care for Patients With Noncancer Illnesses.'],
#  ['PG  ', '1404-1405'],
#  ['LID ', '10.1001/jama.2020.15075 [doi]'],
#  ['FAU ', 'Harrison, Krista L'],
#  ['AU  ', 'Harrison KL'],
#  ['AD  ', 'Division of Geriatrics, University of California, San Francisco.'],
#  ['AD  ',
#   'Philip R. Lee Institute for Health Policy Studies, University of California, San '],
#  ['      Francisco.'],
#  ['FAU ', 'Kotwal, Ashwin A'],
#  ['AU  ', 'Kotwal AA'],
#  ['AD  ', 'Division of Geriatrics, University of California, San Francisco.'],
#  ['AD  ',
#   'San Francisco Veterans Affairs Medical Center, San Francisco, California.'],
#  ['FAU ', 'Smith, Alexander K'],
#  ['AU  ', 'Smith AK'],
#  ['AD  ', 'Division of Geriatrics, University of California, San Francisco.'],
#  ['AD  ',
#   'San Francisco Veterans Affairs Medical Center, San Francisco, California.'],
#  ['LA  ', 'eng'],
#  ['GR  ', 'R03 AG064323/AG/NIA NIH HHS/United States'],
#  ['GR  ', 'K01 AG059831/AG/NIA NIH HHS/United States'],
#  ['GR  ', 'L30 AG060590/AG/NIA NIH HHS/United States'],
#  ['GR  ', 'R01 AG057751/AG/NIA NIH HHS/United States'],
#  ['GR  ', 'P30 AG044281/AG/NIA NIH HHS/United States'],
#  ['GR  ', 'K24 AG068312/AG/NIA NIH HHS/United States'],
#  ['GR  ', 'F32 AG005775/AG/NIA NIH HHS/United States'],
#  ['PT  ', 'Editorial'],
#  ['PT  ', 'Comment'],
#  ['PL  ', 'United States'],
#  ['TA  ', 'JAMA'],
#  ['JT  ', 'JAMA'],
#  ['JID ', '7501160'],
#  ['SB  ', 'AIM'],
#  ['SB  ', 'IM'],
#  ['CON ', 'JAMA. 2020 Oct 13;324(14):1439-1450. PMID: 33048152'],
#  ['MH  ', 'Adult'],
#  ['MH  ', 'Chronic Disease'],
#  ['MH  ', 'Humans'],
#  ['MH  ', '*Palliative Care'],
#  ['MH  ', 'Quality of Life'],
#  ['MH  ', '*Terminal Care'],
#  ['PMC ', 'PMC7771527'],
#  ['MID ', 'NIHMS1656049'],
#  ['EDAT', '2020/10/14 06:00'],
#  ['MHDA', '2020/10/21 06:00'],
#  ['CRDT', '2020/10/13 12:12'],
#  ['PHST', '2020/10/13 12:12 [entrez]'],
#  ['PHST', '2020/10/14 06:00 [pubmed]'],
#  ['PHST', '2020/10/21 06:00 [medline]'],
#  ['AID ', '2771591 [pii]'],
#  ['AID ', '10.1001/jama.2020.15075 [doi]'],
#  ['PST ', 'ppublish'],
#  ['SO  ',
#   'JAMA. 2020 Oct 13;324(14):1404-1405. doi: 10.1001/jama.2020.15075.'],
#  [''],
#  ['PMID', '32965024'],
#  ['OWN ', 'NLM'],
#  ['STAT', 'MEDLINE'],
#  ['DCOM', '20210125'],
#  ['LR  ', '20210125'],
#  ['IS  ', '1532-5415 (Electronic)'],
#  ['IS  ', '0002-8614 (Linking)'],
#  ['VI  ', '69'],
#  ['IP  ', '1'],
#  ['DP  ', '2021 Jan'],
#  ['TI  ',
#   'Social Isolation and Loneliness Among San Francisco Bay Area Older Adults During '],
#  ['      the COVID-19 Shelter-in-Place Orders.'],
#  ['PG  ', '20-29'],
#  ['LID ', '10.1111/jgs.16865 [doi]'],
#  ['AB  ',
#   'BACKGROUND/OBJECTIVES: Physical distancing during the COVID-19 pandemic may have '],
#  ['      unintended, detrimental effects on social isolation and loneliness among older'],
#  ['      adults. Our objectives were to investigate (1) experiences of social isolation'],
#  ['      and loneliness during shelter-in-place orders, and (2) unmet health needs related'],
#  ['      to changes in social interactions. DESIGN: Mixed-methods longitudinal phone-based'],
#  ['      survey administered every 2 weeks. SETTING: Two community sites and an academic'],
#  ['      geriatrics outpatient clinical practice. PARTICIPANTS: A total of 151'],
#  ['      community-dwelling older adults. MEASUREMENTS: We measured social isolation using'],
#  ['      a six-item modified Duke Social Support Index, social interaction subscale, that '],
#  ['      included assessments of video-based and Internet-based socializing. Measures of'],
#  ['      loneliness included self-reported worsened loneliness due to the COVID-19'],
#  ['      pandemic and loneliness severity based on the three-item University of'],
#  ['      California, Los Angeles (UCLA) Loneliness Scale. Participants were invited to'],
#  ['      share open-ended comments about their social experiences. RESULTS: Participants'],
#  ['      were on average aged 75 years (standard deviation = 10), 50% had hearing or'],
#  ['      vision impairment, 64% lived alone, and 26% had difficulty bathing. Participants '],
#  ['      reported social isolation in 40% of interviews, 76% reported minimal video-based '],
#  ['      socializing, and 42% minimal Internet-based socializing. Socially isolated'],
#  ['      participants reported difficulty finding help with functional needs including'],
#  ['      bathing (20% vs 55%; P = .04). More than half (54%) of the participants reported '],
#  ['      worsened loneliness due to COVID-19 that was associated with worsened depression '],
#  ['      (62% vs 9%; P < .001) and anxiety (57% vs 9%; P < .001). Rates of loneliness'],
#  ['      improved on average by time since shelter-in-place orders (4-6 weeks: 46% vs'],
#  ['      13-15 weeks: 27%; P = .009), however, loneliness persisted or worsened for a'],
#  ['      subgroup of participants. Open-ended responses revealed challenges faced by the'],
#  ['      subgroup experiencing persistent loneliness including poor emotional coping and'],
#  ['      discomfort with new technologies. CONCLUSION: Many older adults are adjusting to '],
#  ['      COVID-19 restrictions since the start of shelter-in-place orders. Additional'],
#  ['      steps are critically needed to address the psychological suffering and unmet'],
#  ['      medical needs of those with persistent loneliness or barriers to technology-based'],
#  ['      social interaction.'],
#  ['CI  ', '(c) 2020 The American Geriatrics Society.'],
#  ['FAU ', 'Kotwal, Ashwin A'],
#  ['AU  ', 'Kotwal AA'],
#  ['AUID', 'ORCID: 0000-0002-6137-8512'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, California, USA.'],
#  ['AD  ',
#   'Geriatrics, Palliative, and Extended Care Service Line, San Francisco Veterans'],
#  ['      Affairs Medical Center, San Francisco, California, USA.'],
#  ['FAU ', 'Holt-Lunstad, Julianne'],
#  ['AU  ', 'Holt-Lunstad J'],
#  ['AD  ',
#   'Department of Psychology, Brigham Young University, Provo, Utah, USA.'],
#  ['FAU ', 'Newmark, Rebecca L'],
#  ['AU  ', 'Newmark RL'],
#  ['AUID', 'ORCID: 0000-0001-6162-5619'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, California, USA.'],
#  ['FAU ', 'Cenzer, Irena'],
#  ['AU  ', 'Cenzer I'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, California, USA.'],
#  ['AD  ',
#   'Department of Epidemiology and Biostatistics, University of California, San'],
#  ['      Francisco, , California, USA.'],
#  ['FAU ', 'Smith, Alexander K'],
#  ['AU  ', 'Smith AK'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, California, USA.'],
#  ['AD  ',
#   'Geriatrics, Palliative, and Extended Care Service Line, San Francisco Veterans'],
#  ['      Affairs Medical Center, San Francisco, California, USA.'],
#  ['FAU ', 'Covinsky, Kenneth E'],
#  ['AU  ', 'Covinsky KE'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, California, USA.'],
#  ['AD  ',
#   'Geriatrics, Palliative, and Extended Care Service Line, San Francisco Veterans'],
#  ['      Affairs Medical Center, San Francisco, California, USA.'],
#  ['FAU ', 'Escueta, Danielle P'],
#  ['AU  ', 'Escueta DP'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, California, USA.'],
#  ['FAU ', 'Lee, Jina M'],
#  ['AU  ', 'Lee JM'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, California, USA.'],
#  ['FAU ', 'Perissinotto, Carla M'],
#  ['AU  ', 'Perissinotto CM'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, California, USA.'],
#  ['LA  ', 'eng'],
#  ['GR  ', 'Early Career Faculty Award/Hellman Foundation/International'],
#  ['GR  ', 'Metta Fund/International'],
#  ['GR  ', 'T32GM007618/GM/NIGMS NIH HHS/United States'],
#  ['GR  ', 'K23AG065438/AG/NIA NIH HHS/United States'],
#  ['GR  ', 'P30AG044281/AG/NIA NIH HHS/United States'],
#  ['GR  ', 'R03AG064323/AG/NIA NIH HHS/United States'],
#  ['GR  ',
#   'Kornfield Scholars Award/National Palliative Care Research Center/International'],
#  ['GR  ', 'T32GM007618/GM/NIGMS NIH HHS/United States'],
#  ['GR  ', 'K23AG065438/AG/NIA NIH HHS/United States'],
#  ['GR  ', 'P30AG044281/AG/NIA NIH HHS/United States'],
#  ['GR  ', 'R03AG064323/AG/NIA NIH HHS/United States'],
#  ['PT  ', 'Journal Article'],
#  ['PT  ', 'Research Support, N.I.H., Extramural'],
#  ['PT  ', "Research Support, Non-U.S. Gov't"],
#  ['DEP ', '20201009'],
#  ['PL  ', 'United States'],
#  ['TA  ', 'J Am Geriatr Soc'],
#  ['JT  ', 'Journal of the American Geriatrics Society'],
#  ['JID ', '7503062'],
#  ['SB  ', 'IM'],
#  ['MH  ', 'Aged'],
#  ['MH  ', 'Aged, 80 and over'],
#  ['MH  ', 'COVID-19/*prevention & control'],
#  ['MH  ', 'Female'],
#  ['MH  ', 'Geriatric Assessment'],
#  ['MH  ', 'Humans'],
#  ['MH  ', 'Independent Living/*psychology'],
#  ['MH  ', 'Loneliness/*psychology'],
#  ['MH  ', 'Longitudinal Studies'],
#  ['MH  ', 'Male'],
#  ['MH  ', 'Physical Distancing'],
#  ['MH  ', 'Psychiatric Status Rating Scales'],
#  ['MH  ', 'Quarantine/*psychology'],
#  ['MH  ', 'SARS-CoV-2'],
#  ['MH  ', 'San Francisco'],
#  ['MH  ', 'Social Isolation/*psychology'],
#  ['PMC ', 'PMC7536935'],
#  ['OTO ', 'NOTNLM'],
#  ['OT  ', '*COVID-19'],
#  ['OT  ', '*loneliness'],
#  ['OT  ', '*older adults'],
#  ['OT  ', '*social isolation'],
#  ['OT  ', '*technology'],
#  ['EDAT', '2020/09/24 06:00'],
#  ['MHDA', '2021/01/26 06:00'],
#  ['CRDT', '2020/09/23 09:03'],
#  ['PHST', '2020/07/29 00:00 [received]'],
#  ['PHST', '2020/09/16 00:00 [revised]'],
#  ['PHST', '2020/09/17 00:00 [accepted]'],
#  ['PHST', '2020/09/24 06:00 [pubmed]'],
#  ['PHST', '2021/01/26 06:00 [medline]'],
#  ['PHST', '2020/09/23 09:03 [entrez]'],
#  ['AID ', '10.1111/jgs.16865 [doi]'],
#  ['PST ', 'ppublish'],
#  ['SO  ',
#   'J Am Geriatr Soc. 2021 Jan;69(1):20-29. doi: 10.1111/jgs.16865. Epub 2020 Oct 9.'],
#  [''],
#  ['PMID', '32865472'],
#  ['OWN ', 'NLM'],
#  ['STAT', 'In-Data-Review'],
#  ['LR  ', '20210303'],
#  ['IS  ', '1557-7740 (Electronic)'],
#  ['IS  ', '1557-7740 (Linking)'],
#  ['VI  ', '24'],
#  ['IP  ', '3'],
#  ['DP  ', '2021 Mar'],
#  ['TI  ',
#   'A Toolkit for Community-Based, Medicaid-Funded Case Managers to Introduce Advance'],
#  ['      Care Planning to Frail, Older Adults: A Pilot Study.'],
#  ['PG  ', '428-432'],
#  ['LID ', '10.1089/jpm.2020.0200 [doi]'],
#  ['AB  ',
#   'Background: Advance care planning (ACP) among frail, older adults receiving'],
#  ['      in-home care is low. Leveraging case managers to introduce ACP may increase'],
#  ['      engagement. Objective: Pilot an ACP-Toolkit for case managers and their clients. '],
#  ['      Design: Feasibility pilot of an ACP-Toolkit for case managers to introduce ACP'],
#  ['      and the PREPAREforYourCare.org website and advance directives. Setting/Subjects: '],
#  ['      Case managers from four local aging service organizations who referred'],
#  ['      English-speaking clients >/=55 years old. Measurements: Using validated surveys'],
#  ["      (five-point Likert scales), we assessed changes in case managers' attitudes,"],
#  ["      confidence, and readiness to facilitate ACP and clients' readiness to engage in"],
#  ['      ACP from baseline to follow-up (one-week) using Wilcoxon signed-rank tests.'],
#  ['      Results: We enrolled 9 case managers and 12 clients (median age 69 [standard'],
#  ["      deviation 8], 75% minority race/ethnicity). At follow-up, case managers'"],
#  ["      confidence increased (3.2 [0.7] to 4.2 [0.7]; p = 0.02), and clients' readiness"],
#  ['      increased (2.8 [1.5] to 3.4 [1.4]; p = 0.06). All case managers agreed the'],
#  ['      Toolkit was easy to use, helped start ACP conversations, and would recommend it'],
#  ['      to others. All clients found the Toolkit easy to understand and were comfortable '],
#  ['      with case managers using it. Nearly all clients (92%) would recommend it to'],
#  ['      others. Suggestions for improvement included offering the Toolkit in other'],
#  ['      languages and disseminating it in clinical and community settings. Conclusions:'],
#  ['      The ACP-Toolkit resulted in higher case manager confidence in facilitating ACP'],
#  ['      and client readiness to engage in ACP, and usability was high. A brief'],
#  ['      ACP-Toolkit may be a feasible solution to increase ACP engagement among frail,'],
#  ['      older adults receiving in-home care.'],
#  ['FAU ', 'Nouri, Sarah S'],
#  ['AU  ', 'Nouri SS'],
#  ['AD  ',
#   'Division of General Internal Medicine, Department of Medicine, University of'],
#  ['      California, San Francisco, San Francisco, California, USA.'],
#  ['FAU ', 'Ritchie, Christine'],
#  ['AU  ', 'Ritchie C'],
#  ['AD  ',
#   'Division of Palliative Care and Geriatric Medicine, Department of Medicine,'],
#  ['      Massachusetts General Hospital and Harvard Medical School, Boston, Massachusetts,'],
#  ['      USA.'],
#  ['FAU ', 'Volow, Aiesha'],
#  ['AU  ', 'Volow A'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, San Francisco, California, USA.'],
#  ['FAU ', 'Li, Brookelle'],
#  ['AU  ', 'Li B'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, San Francisco, California, USA.'],
#  ['FAU ', 'McSpadden, Shireen'],
#  ['AU  ', 'McSpadden S'],
#  ['AD  ',
#   'San Francisco Department of Disability and Aging Services, San Francisco,'],
#  ['      California, USA.'],
#  ['FAU ', 'Dearman, Kelly'],
#  ['AU  ', 'Dearman K'],
#  ['AD  ',
#   'San Francisco In-Home Supportive Services Public Authority, San Francisco,'],
#  ['      California, USA.'],
#  ['FAU ', 'Kotwal, Ashwin'],
#  ['AU  ', 'Kotwal A'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, San Francisco, California, USA.'],
#  ['FAU ', 'Sudore, Rebecca L'],
#  ['AU  ', 'Sudore RL'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, San Francisco, California, USA.'],
#  ['LA  ', 'eng'],
#  ['GR  ', 'K24 AG054415/AG/NIA NIH HHS/United States'],
#  ['PT  ', 'Journal Article'],
#  ['DEP ', '20200827'],
#  ['PL  ', 'United States'],
#  ['TA  ', 'J Palliat Med'],
#  ['JT  ', 'Journal of palliative medicine'],
#  ['JID ', '9808462'],
#  ['SB  ', 'IM'],
#  ['PMC ', 'PMC7894043'],
#  ['OTO ', 'NOTNLM'],
#  ['OT  ', 'advance care planning'],
#  ['OT  ', 'case managers'],
#  ['OT  ', 'community-based'],
#  ['OT  ', 'vulnerable populations'],
#  ['EDAT', '2020/09/01 06:00'],
#  ['MHDA', '2020/09/01 06:00'],
#  ['CRDT', '2020/09/01 06:00'],
#  ['PHST', '2020/09/01 06:00 [pubmed]'],
#  ['PHST', '2020/09/01 06:00 [medline]'],
#  ['PHST', '2020/09/01 06:00 [entrez]'],
#  ['AID ', '10.1089/jpm.2020.0200 [doi]'],
#  ['PST ', 'ppublish'],
#  ['SO  ',
#   'J Palliat Med. 2021 Mar;24(3):428-432. doi: 10.1089/jpm.2020.0200. Epub 2020 Aug '],
#  ['      27.'],
#  [''],
#  ['PMID', '32803486'],
#  ['OWN ', 'NLM'],
#  ['STAT', 'In-Data-Review'],
#  ['LR  ', '20200818'],
#  ['IS  ', '1534-6269 (Electronic)'],
#  ['IS  ', '1523-3790 (Linking)'],
#  ['VI  ', '22'],
#  ['IP  ', '11'],
#  ['DP  ', '2020 Aug 15'],
#  ['TI  ',
#   "Cancer Screening Among Older Adults: a Geriatrician's Perspective on Breast,"],
#  ['      Cervical, Colon, Prostate, and Lung Cancer Screening.'],
#  ['PG  ', '108'],
#  ['LID ', '10.1007/s11912-020-00968-x [doi]'],
#  ['AB  ',
#   'PURPOSE OF REVIEW: We summarize the evidence of benefits, harms, and tools to'],
#  ['      assist in individualized decisions among older adults in screening for breast,'],
#  ['      prostate, colon, lung, and cervical cancer. RECENT FINDINGS: The benefits of'],
#  ['      cancer screening in older adults remain unclear due to minimal inclusion of'],
#  ['      adults > 75 years old in most randomized controlled trials. Indirect evidence'],
#  ['      suggests that the benefits of screening seen in younger adults (< 70 years old)'],
#  ['      can be extrapolated to older adults when they have an estimated life expectancy'],
#  ['      of at least 10 years. However, older adults, especially those with limited life'],
#  ['      expectancy, may be at increased risk for experiencing harms of screening,'],
#  ['      including overdiagnosis of clinically unimportant diseases, complications from'],
#  ['      diagnostic procedures, and distress after false positive test results. We provide'],
#  ['      a framework to integrate key factors such as health status, risks and benefits of'],
#  ['      specific tests, and patient preferences to guide clinicians in cancer screening'],
#  ['      decisions in older adults.'],
#  ['FAU ', 'Kotwal, Ashwin A'],
#  ['AU  ', 'Kotwal AA'],
#  ['AUID', 'ORCID: http://orcid.org/0000-0002-6137-8512'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, USA. ashwin.kotwal@ucsf.edu.'],
#  ['AD  ',
#   'Geriatrics, Palliative, and Extended Care Service Line, San Francisco Veterans'],
#  ['      Affairs Medical Center, 4150 Clement Street (181G), San Francisco, CA, 94121,'],
#  ['      USA. ashwin.kotwal@ucsf.edu.'],
#  ['FAU ', 'Walter, Louise C'],
#  ['AU  ', 'Walter LC'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, USA.'],
#  ['AD  ',
#   'Geriatrics, Palliative, and Extended Care Service Line, San Francisco Veterans'],
#  ['      Affairs Medical Center, 4150 Clement Street (181G), San Francisco, CA, 94121,'],
#  ['      USA.'],
#  ['LA  ', 'eng'],
#  ['PT  ', 'Journal Article'],
#  ['PT  ', 'Review'],
#  ['DEP ', '20200815'],
#  ['PL  ', 'United States'],
#  ['TA  ', 'Curr Oncol Rep'],
#  ['JT  ', 'Current oncology reports'],
#  ['JID ', '100888967'],
#  ['SB  ', 'IM'],
#  ['OTO ', 'NOTNLM'],
#  ['OT  ', 'Cancer screening'],
#  ['OT  ', 'Colon cancer'],
#  ['OT  ', 'Lung cancer'],
#  ['OT  ', 'Mammogram'],
#  ['OT  ', 'Older adults'],
#  ['OT  ', 'PSA test'],
#  ['EDAT', '2020/08/18 06:00'],
#  ['MHDA', '2020/08/18 06:00'],
#  ['CRDT', '2020/08/18 06:00'],
#  ['PHST', '2020/08/18 06:00 [entrez]'],
#  ['PHST', '2020/08/18 06:00 [pubmed]'],
#  ['PHST', '2020/08/18 06:00 [medline]'],
#  ['AID ', '10.1007/s11912-020-00968-x [doi]'],
#  ['AID ', '10.1007/s11912-020-00968-x [pii]'],
#  ['PST ', 'epublish'],
#  ['SO  ',
#   'Curr Oncol Rep. 2020 Aug 15;22(11):108. doi: 10.1007/s11912-020-00968-x.'],
#  [''],
#  ['PMID', '32422084'],
#  ['OWN ', 'NLM'],
#  ['STAT', 'MEDLINE'],
#  ['DCOM', '20200924'],
#  ['LR  ', '20201218'],
#  ['IS  ', '1539-3704 (Electronic)'],
#  ['IS  ', '0003-4819 (Linking)'],
#  ['VI  ', '173'],
#  ['IP  ', '6'],
#  ['DP  ', '2020 Sep 15'],
#  ['TI  ',
#   'The New Normal: Key Considerations for Effective Serious Illness Communication'],
#  ['      Over Video or Telephone During the Coronavirus Disease 2019 (COVID-19) Pandemic.'],
#  ['PG  ', '486-488'],
#  ['LID ', '10.7326/M20-1982 [doi]'],
#  ['FAU ', 'Flint, Lynn'],
#  ['AU  ', 'Flint L'],
#  ['AD  ',
#   'University of California-San Francisco, and Geriatrics, Palliative, and Extended '],
#  ['      Care Service Line, San Francisco Veterans Affairs Medical Center, San Francisco, '],
#  ['      California (L.F., A.K.).'],
#  ['FAU ', 'Kotwal, Ashwin'],
#  ['AU  ', 'Kotwal A'],
#  ['AD  ',
#   'University of California-San Francisco, and Geriatrics, Palliative, and Extended '],
#  ['      Care Service Line, San Francisco Veterans Affairs Medical Center, San Francisco, '],
#  ['      California (L.F., A.K.).'],
#  ['LA  ', 'eng'],
#  ['PT  ', 'Editorial'],
#  ['DEP ', '20200514'],
#  ['PL  ', 'United States'],
#  ['TA  ', 'Ann Intern Med'],
#  ['JT  ', 'Annals of internal medicine'],
#  ['JID ', '0372351'],
#  ['SB  ', 'AIM'],
#  ['SB  ', 'IM'],
#  ['MH  ', 'Betacoronavirus'],
#  ['MH  ', 'COVID-19'],
#  ['MH  ', 'Communication Barriers'],
#  ['MH  ', 'Coronavirus Infections/*epidemiology'],
#  ['MH  ', 'Humans'],
#  ['MH  ', 'Pandemics'],
#  ['MH  ', '*Patient Isolation'],
#  ['MH  ', '*Physician-Patient Relations'],
#  ['MH  ', 'Pneumonia, Viral/*epidemiology'],
#  ['MH  ', '*Professional-Family Relations'],
#  ['MH  ', 'SARS-CoV-2'],
#  ['MH  ', '*Telephone'],
#  ['MH  ', '*Videoconferencing'],
#  ['PMC ', 'PMC7236893'],
#  ['EDAT', '2020/05/19 06:00'],
#  ['MHDA', '2020/09/25 06:00'],
#  ['CRDT', '2020/05/19 06:00'],
#  ['PHST', '2020/05/19 06:00 [pubmed]'],
#  ['PHST', '2020/09/25 06:00 [medline]'],
#  ['PHST', '2020/05/19 06:00 [entrez]'],
#  ['AID ', '10.7326/M20-1982 [doi]'],
#  ['PST ', 'ppublish'],
#  ['SO  ',
#   'Ann Intern Med. 2020 Sep 15;173(6):486-488. doi: 10.7326/M20-1982. Epub 2020 May '],
#  ['      14.'],
#  [''],
#  ['PMID', '32359072'],
#  ['OWN ', 'NLM'],
#  ['STAT', 'MEDLINE'],
#  ['DCOM', '20210302'],
#  ['LR  ', '20210302'],
#  ['IS  ', '1532-5415 (Electronic)'],
#  ['IS  ', '0002-8614 (Linking)'],
#  ['VI  ', '68'],
#  ['IP  ', '6'],
#  ['DP  ', '2020 Jun'],
#  ['TI  ',
#   '"Social Distancing" Amid a Crisis in Social Isolation and Loneliness.'],
#  ['PG  ', 'E27-E29'],
#  ['LID ', '10.1111/jgs.16527 [doi]'],
#  ['FAU ', 'Cudjoe, Thomas K M'],
#  ['AU  ', 'Cudjoe TKM'],
#  ['AUID', 'ORCID: 0000-0002-2590-209X'],
#  ['AD  ',
#   'Division of Geriatric Medicine and Gerontology, Department of Medicine, Johns'],
#  ['      Hopkins University School of Medicine, Baltimore, Maryland.'],
#  ['FAU ', 'Kotwal, Ashwin A'],
#  ['AU  ', 'Kotwal AA'],
#  ['AUID', 'ORCID: 0000-0002-6137-8512'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, San Francisco, California.'],
#  ['AD  ',
#   'Geriatrics, Palliative, and Extended Care Service Line, San Francisco Veterans'],
#  ['      Affairs Medical Center, San Francisco, California.'],
#  ['LA  ', 'eng'],
#  ['GR  ', 'R03 AG064253/AG/NIA NIH HHS/United States'],
#  ['GR  ', 'R03 AG064323/AG/NIA NIH HHS/United States'],
#  ['GR  ', 'R03AG064253/AG/NIA NIH HHS/United States'],
#  ['GR  ', 'R03AG064323/AG/NIA NIH HHS/United States'],
#  ['PT  ', 'Letter'],
#  ['PT  ', 'Research Support, N.I.H., Extramural'],
#  ['DEP ', '20200515'],
#  ['PL  ', 'United States'],
#  ['TA  ', 'J Am Geriatr Soc'],
#  ['JT  ', 'Journal of the American Geriatrics Society'],
#  ['JID ', '7503062'],
#  ['SB  ', 'IM'],
#  ['MH  ', 'Aging'],
#  ['MH  ', 'COVID-19/*psychology'],
#  ['MH  ', 'Humans'],
#  ['MH  ', 'Loneliness/*psychology'],
#  ['MH  ', 'Mental Health'],
#  ['MH  ', '*Physical Distancing'],
#  ['MH  ', 'Social Isolation/*psychology'],
#  ['PMC ', 'PMC7267573'],
#  ['EDAT', '2020/05/03 06:00'],
#  ['MHDA', '2021/03/03 06:00'],
#  ['CRDT', '2020/05/03 06:00'],
#  ['PHST', '2020/04/13 00:00 [received]'],
#  ['PHST', '2020/04/20 00:00 [revised]'],
#  ['PHST', '2020/04/21 00:00 [accepted]'],
#  ['PHST', '2020/05/03 06:00 [pubmed]'],
#  ['PHST', '2021/03/03 06:00 [medline]'],
#  ['PHST', '2020/05/03 06:00 [entrez]'],
#  ['AID ', '10.1111/jgs.16527 [doi]'],
#  ['PST ', 'ppublish'],
#  ['SO  ',
#   'J Am Geriatr Soc. 2020 Jun;68(6):E27-E29. doi: 10.1111/jgs.16527. Epub 2020 May'],
#  ['      15.'],
#  [''],
#  ['PMID', '32356919'],
#  ['OWN ', 'NLM'],
#  ['STAT', 'MEDLINE'],
#  ['DCOM', '20210302'],
#  ['LR  ', '20210302'],
#  ['IS  ', '1532-5415 (Electronic)'],
#  ['IS  ', '0002-8614 (Linking)'],
#  ['VI  ', '68'],
#  ['IP  ', '8'],
#  ['DP  ', '2020 Aug'],
#  ['TI  ',
#   'Integration of an Objective Cognitive Assessment Into a Prognostic Index for'],
#  ['      5-Year Mortality Prediction.'],
#  ['PG  ', '1796-1802'],
#  ['LID ', '10.1111/jgs.16451 [doi]'],
#  ['AB  ',
#   'BACKGROUND/OBJECTIVES: Prognostic indices rarely include cognition. We determined'],
#  ['      if a comprehensive cognitive screen or brief individual items were associated'],
#  ['      with improved mortality predictions of a widely used prognostic index. DESIGN,'],
#  ['      SETTING, AND PARTICIPANTS: The National Social Life Health and Aging Project Wave'],
#  ['      2, a nationally representative, cross-sectional, in-home survey conducted in 2010'],
#  ['      to 2011 on 3,199 community-dwelling adults aged 60 to 99 years. MEASUREMENTS:'],
#  ['      Cognition was measured using a Survey-Adapted Montreal Cognitive Assessment'],
#  ['      (MoCA-SA) grouped into three screened categories: screen normal (>/=24 points),'],
#  ['      screen positive for mild cognitive impairment (18-23 points), and screen positive'],
#  ['      for dementia (<18 points). Single-item cognitive measures included clock-draw and'],
#  ['      five-word delayed recall. We constructed a modified Lee Prognostic Index (range ='],
#  ['      0-18 points) based on age, behavior, function, and comorbidities shown to predict'],
#  ['      long-term mortality. We used logistic regression and the fraction of new'],
#  ['      information provided to determine if each cognitive measure improved the Lee'],
#  ["      index's 5-year mortality prediction. RESULTS: The sample was 54% female and had a"],
#  ['      mean age of 72 years, MoCA-SA score of 22 (SD = 4.5), and Lee index of 7 (SD ='],
#  ["      3). Regression analysis indicated the MoCA-SA modestly improved the Lee index's"],
#  ['      mortality prediction (P < .001; fraction of new information provided = 0.06); for'],
#  ['      low Lee index scores (<4 points), the absolute mortality rate difference was 7%'],
#  ['      by cognitive status; and for higher Lee index scores (4-7 points or 8-12 points),'],
#  ['      the absolute mortality rate difference was 15% by cognitive status. The'],
#  ['      clock-draw and delayed-recall items added similar value to mortality predictions '],
#  ['      as the longer MoCA-SA. Cognition had the third highest fraction of new'],
#  ['      information of all 13 Lee index items. CONCLUSION: Incorporating a brief measure '],
#  ['      of cognition into a modified Lee index, even with single items, resulted in more '],
#  ['      accurate 5-year mortality risk predictions. Cognition should be included in'],
#  ['      prognostic calculators in older adults given its independent association with'],
#  ['      mortality risk. J Am Geriatr Soc 68:1796-1802, 2020.'],
#  ['CI  ', '(c) 2020 The American Geriatrics Society.'],
#  ['FAU ', 'Kotwal, Ashwin A'],
#  ['AU  ', 'Kotwal AA'],
#  ['AUID', 'ORCID: 0000-0002-6137-8512'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, School of Medicine, San Francisco, California, USA.'],
#  ['AD  ',
#   'Geriatrics, Palliative, and Extended Care Service Line, San Francisco Veterans'],
#  ['      Affairs Medical, San Francisco, California, USA.'],
#  ['FAU ', 'Lee, Sei J'],
#  ['AU  ', 'Lee SJ'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, School of Medicine, San Francisco, California, USA.'],
#  ['AD  ',
#   'Geriatrics, Palliative, and Extended Care Service Line, San Francisco Veterans'],
#  ['      Affairs Medical, San Francisco, California, USA.'],
#  ['FAU ', 'Dale, William'],
#  ['AU  ', 'Dale W'],
#  ['AD  ',
#   'Department of Supportive Care Medicine, City of Hope National Medical Center,'],
#  ['      Duarte, California, USA.'],
#  ['FAU ', 'Boscardin, W John'],
#  ['AU  ', 'Boscardin WJ'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, School of Medicine, San Francisco, California, USA.'],
#  ['AD  ',
#   'Geriatrics, Palliative, and Extended Care Service Line, San Francisco Veterans'],
#  ['      Affairs Medical, San Francisco, California, USA.'],
#  ['AD  ',
#   'Department of Epidemiology and Biostatistics, University of California, San'],
#  ['      Francisco, San Francisco, California, USA.'],
#  ['FAU ', 'Waite, Linda J'],
#  ['AU  ', 'Waite LJ'],
#  ['AD  ',
#   'Department of Sociology, University of Chicago, Chicago, Illinois, USA.'],
#  ['FAU ', 'Smith, Alexander K'],
#  ['AU  ', 'Smith AK'],
#  ['AD  ',
#   'Division of Geriatrics, Department of Medicine, University of California, San'],
#  ['      Francisco, School of Medicine, San Francisco, California, USA.'],
#  ['AD  ',
#   'Geriatrics, Palliative, and Extended Care Service Line, San Francisco Veterans'],
#  ['      Affairs Medical, San Francisco, California, USA.'],
#  ['LA  ', 'eng'],
#  ['GR  ', 'AG/NIA NIH HHS/United States'],
#  ['GR  ', 'R01AG057751/NH/NIH HHS/United States'],
#  ['GR  ', 'I01 HX002135/HX/HSRD VA/United States'],
#  ['GR  ', 'R03AG064323/NH/NIH HHS/United States'],
#  ['GR  ', 'R01AG043538; R01AG048511; R37AG030481/NH/NIH HHS/United States'],
#  ['GR  ', 'R01AG043538/NH/NIH HHS/United States'],
#  ['GR  ', 'R01AG0477897/NH/NIH HHS/United States'],
#  ['GR  ', 'HX/HSRD VA/United States'],
#  ['PT  ', 'Journal Article'],
#  ['PT  ', 'Research Support, N.I.H., Extramural'],
#  ['PT  ', "Research Support, U.S. Gov't, Non-P.H.S."],
#  ['DEP ', '20200501'],
#  ['PL  ', 'United States'],
#  ['TA  ', 'J Am Geriatr Soc'],
#  ['JT  ', 'Journal of the American Geriatrics Society'],
#  ['JID ', '7503062'],
#  ['SB  ', 'IM'],
#  ['MH  ', 'Aged'],
#  ['MH  ', 'Aged, 80 and over'],
#  ['MH  ', 'Aging/psychology'],
#  ['MH  ', 'Cognition'],
#  ['MH  ', 'Cognitive Dysfunction/*diagnosis/*mortality/psychology'],
#  ['MH  ', 'Cross-Sectional Studies'],
#  ['MH  ', 'Female'],
#  ['MH  ', 'Geriatric Assessment/methods/*statistics & numerical data'],
#  ['MH  ', '*Health Status Indicators'],
#  ['MH  ', 'Humans'],
#  ['MH  ', 'Independent Living/psychology'],
#  ['MH  ', 'Male'],
#  ['MH  ', 'Mental Competency/psychology'],
#  ['MH  ', 'Mental Status and Dementia Tests/*statistics & numerical data'],
#  ['MH  ', 'Middle Aged'],
#  ['MH  ', 'Predictive Value of Tests'],
#  ['MH  ', 'Prognosis'],
#  ['MH  ', 'Regression Analysis'],
#  ['MH  ', 'Risk Assessment'],
#  ['EDAT', '2020/05/02 06:00'],
#  ['MHDA', '2021/03/03 06:00'],
#  ['CRDT', '2020/05/02 06:00'],
#  ['PHST', '2019/12/03 00:00 [received]'],
#  ['PHST', '2020/03/12 00:00 [revised]'],
#  ['PHST', '2020/03/15 00:00 [accepted]'],
#  ['PHST', '2020/05/02 06:00 [pubmed]'],
#  ['PHST', '2021/03/03 06:00 [medline]'],
#  ['PHST', '2020/05/02 06:00 [entrez]'],
#  ['AID ', '10.1111/jgs.16451 [doi]'],
#  ['PST ', 'ppublish'],
#  ['SO  ',
#   'J Am Geriatr Soc. 2020 Aug;68(8):1796-1802. doi: 10.1111/jgs.16451. Epub 2020 May'],
#  ['      1.'],
#  [''],
#  ['PMID', '31775021'],
#  ['OWN ', 'NLM'],
#  ['STAT', 'In-Process'],
#  ['LR  ', '20210122'],
#  ['IS  ', '1873-6513 (Electronic)'],
#  ['IS  ', '0885-3924 (Linking)'],
#  ['VI  ', '59'],
#  ['IP  ', '4'],
#  ['DP  ', '2020 Apr'],
#  ['TI  ',
#   'Opportunities for Palliative Care in Patients With Burn Injury-A Systematic'],
#  ['      Review.'],
#  ['PG  ', '916-931.e1'],
#  ['LID ', 'S0885-3924(19)30669-4 [pii]'],
#  ['LID ', '10.1016/j.jpainsymman.2019.11.014 [doi]'],
#  ['AB  ',
#   'CONTEXT: Patients with significant burn injuries likely have palliative care'],
#  ['      needs. OBJECTIVES: We performed a systematic review of existing evidence'],
#  ['      concerning the palliative care needs of burn patients. METHODS: Through November '],
#  ['      26, 2018, we systematically searched PubMed, CINAHL, Embase, Web of Science, and '],
#  ['      Scopus, using terms representing burn injuries and the eight domains of quality'],
#  ['      palliative care as outlined by the National Consensus Project for Quality'],
#  ['      Palliative Care. Eligible articles involved burn-injured patients treated with an'],
#  ['      intervention targeting at least one of the eight domains. RESULTS: Our searches'],
#  ['      yielded 7532 unique records, which led to 238 articles for full review and 88'],
#  ['      studies that met inclusion criteria. Seventy-five studies addressed the domain'],
#  ['      physical aspects of care and merit a separate systematic review; 13 studies were '],
#  ['      included in our final review. Four of the seven domains-processes of care,'],
#  ['      psychologic symptoms, social aspects, and end of life-were addressed by studies'],
#  ['      but three domains-spiritual, cultural, or ethics-were unaddressed. Included'],
#  ['      studies highlight potential benefits from peridischarge self-care education'],
#  ['      programs, peer support, and group therapy in improving quality of life. In'],
#  ['      patients with severe injuries, end-of-life decision-making protocols were'],
#  ['      associated with increased utilization of comfort-focused treatments. CONCLUSION: '],
#  ['      Most existing palliative care-related research in burn patients addresses'],
#  ['      interventions for physical symptoms with minimal literature concerning other'],
#  ['      domains. Opportunities exist for further research of palliative care in burn'],
#  ['      populations with emphasis on addressing interventions for all domains and better '],
#  ['      standardizing the language and outcomes for the palliative care interventions.'],
#  ['CI  ',
#   'Copyright (c) 2019 American Academy of Hospice and Palliative Medicine. Published'],
#  ['      by Elsevier Inc. All rights reserved.'],
#  ['FAU ', 'Cook, Allyson C'],
#  ['AU  ', 'Cook AC'],
#  ['AD  ',
#   'Department of Medicine, University of California San Francisco, San Francisco,'],
#  ['      California, USA. Electronic address: allyson.Cook@ucsf.edu.'],
#  ['FAU ', 'Langston, Jessica A'],
#  ['AU  ', 'Langston JA'],
#  ['AD  ',
#   'Department of Medicine, VA NorCal Health Care System, Sacramento, California,'],
#  ['      USA.'],
#  ['FAU ', 'Jaramillo, Joshua D'],
#  ['AU  ', 'Jaramillo JD'],
#  ['AD  ',
#   'Department of Surgery, Stanford University, Stanford, California, USA.'],
#  ['FAU ', 'Edwards, Kristin E'],
#  ['AU  ', 'Edwards KE'],
#  ['AD  ',
#   'Department of Medicine-Palliative Care, Bridgeport Hospital, Yale New Haven'],
#  ['      Health, Bridgeport, Connecticut, USA.'],
#  ['FAU ', 'Wong, Hong-Nei'],
#  ['AU  ', 'Wong HN'],
#  ['AD  ',
#   'Lane Medical Library & Knowledge Management Center, Stanford University School of'],
#  ['      Medicine, Stanford, California, USA.'],
#  ['FAU ', 'Aslakson, Rebecca A'],
#  ['AU  ', 'Aslakson RA'],
#  ['AD  ',
#   'Departments of Medicine & Anesthesiology, Stanford University, Stanford,'],
#  ['      California, USA.'],
#  ['CN  ',
#   'American Academy of Hospice and Palliative Medicine Research Committee Writing'],
#  ['      Group'],
#  ['LA  ', 'eng'],
#  ['PT  ', 'Journal Article'],
#  ['DEP ', '20191124'],
#  ['PL  ', 'United States'],
#  ['TA  ', 'J Pain Symptom Manage'],
#  ['JT  ', 'Journal of pain and symptom management'],
#  ['JID ', '8605836'],
#  ['SB  ', 'IM'],
#  ['OTO ', 'NOTNLM'],
#  ['OT  ', '*Burn'],
#  ['OT  ', '*domains of quality palliative care'],
#  ['OT  ', '*palliative care'],
#  ['IR  ', 'Aslakson R'],
#  ['FIR ', 'Aslakson, Rebecca'],
#  ['IR  ', 'Ast K'],
#  ['FIR ', 'Ast, Katherine'],
#  ['IR  ', 'Carroll T'],
#  ['FIR ', 'Carroll, Thomas'],
#  ['IR  ', 'Dzeng E'],
#  ['FIR ', 'Dzeng, Elizabeth'],
#  ['IR  ', 'Frechman E'],
#  ['FIR ', 'Frechman, Erica'],
#  ['IR  ', 'Goett R'],
#  ['FIR ', 'Goett, Rebecca'],
#  ['IR  ', 'Harrison KL'],
#  ['FIR ', 'Harrison, Krista L'],
#  ['IR  ', 'Kaye EC'],
#  ['FIR ', 'Kaye, Erica C'],
#  ['IR  ', 'Kotwal A'],
#  ['FIR ', 'Kotwal, Ashwin'],
#  ['IR  ', 'LeBlanc TW'],
#  ['FIR ', 'LeBlanc, Thomas W'],
#  ['IR  ', 'Lo SS'],
#  ['FIR ', 'Lo, Shelly S'],
#  ['IR  ', 'Nageswaran S'],
#  ['FIR ', 'Nageswaran, Savithri'],
#  ['IR  ', 'Powell V'],
#  ['FIR ', 'Powell, Victoria'],
#  ['IR  ', 'Powers J'],
#  ['FIR ', 'Powers, James'],
#  ['IR  ', 'Rotella J'],
#  ['FIR ', 'Rotella, Joseph'],
#  ['IR  ', 'Ullrich C'],
#  ['FIR ', 'Ullrich, Christina'],
#  ['IR  ', 'Vickey T'],
#  ['FIR ', 'Vickey, Theresa'],
#  ['IR  ', 'Wong S'],
#  ['FIR ', 'Wong, Susan'],
#  ['EDAT', '2019/11/28 06:00'],
#  ['MHDA', '2019/11/28 06:00'],
#  ['CRDT', '2019/11/28 06:00'],
#  ['PHST', '2019/09/06 00:00 [received]'],
#  ['PHST', '2019/11/12 00:00 [revised]'],
#  ['PHST', '2019/11/13 00:00 [accepted]'],
#  ['PHST', '2019/11/28 06:00 [pubmed]'],
#  ['PHST', '2019/11/28 06:00 [medline]'],
#  ['PHST', '2019/11/28 06:00 [entrez]'],
#  ['AID ', 'S0885-3924(19)30669-4 [pii]'],
#  ['AID ', '10.1016/j.jpainsymman.2019.11.014 [doi]'],
#  ['PST ', 'ppublish'],
#  ['SO  ', 'J Pain Symptom Manage. 2020 Apr;59(4):916-931.e1. doi:'],
#  ['      10.1016/j.jpainsymman.2019.11.014. Epub 2019 Nov 24.'],
#  ['']]

# %% [markdown]
# df= {}
#
# def create_df(pubmed_list):
#     for line_item in pubmed_list:
#         try:
#             df[line_item[0]] = line_item[1]
#         except Exception:
#             if line_item == ['']:
#                 pass
# make_df = create_df(pubmed_list)
# df

# %%
df = DataFrame(pubmed_list, columns=['key', 'value'])
df
# Out:
#                                                    key  \
# 0
# 1                                                 PMID
# 2                                                 OWN
# 3                                                 STAT
# 4                                                 DCOM
# ..                                                 ...
# 829                                               AID
# 830                                               PST
# 831                                               SO
# 832        10.1016/j.jpainsymman.2019.11.014. Epub ...
# 833
#
#                                                  value
# 0                                                 None
# 1                                             33099456
# 2                                                  NLM
# 3                                              MEDLINE
# 4                                             20201030
# ..                                                 ...
# 829            10.1016/j.jpainsymman.2019.11.014 [doi]
# 830                                           ppublish
# 831  J Pain Symptom Manage. 2020 Apr;59(4):916-931....
# 832                                               None
# 833                                               None
#
# [834 rows x 2 columns]

# %%
df.transpose()
# Out:
#         0         1     2        3         4         5    \
# key              PMID  OWN      STAT      DCOM      LR
# value  None  33099456   NLM  MEDLINE  20201030  20201030
#
#                           6                    7     8     9    ...  \
# key                      IS                   IS    VI    IP    ...
# value  1557-9859 (Electronic)  0025-7125 (Linking)   104     6  ...
#
#                                824                        825  \
# key                           PHST                       PHST
# value  2019/11/13 00:00 [accepted]  2019/11/28 06:00 [pubmed]
#
#                               826                        827  \
# key                          PHST                       PHST
# value  2019/11/28 06:00 [medline]  2019/11/28 06:00 [entrez]
#
#                                828                                      829  \
# key                           AID                                      AID
# value  S0885-3924(19)30669-4 [pii]  10.1016/j.jpainsymman.2019.11.014 [doi]
#
#             830                                                831  \
# key        PST                                                SO
# value  ppublish  J Pain Symptom Manage. 2020 Apr;59(4):916-931....
#
#                                                      832   833
# key          10.1016/j.jpainsymman.2019.11.014. Epub ...
# value                                               None  None
#
# [2 rows x 834 columns]

# %%
df = df[~df.rows[0:].str.contains('PMID')].reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-7542cad781ee> in <module>
# ----> 1 df = df[~df.rows[0:].str.contains('PMID')].reset_index(drop=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
#publications_list = pd.read_csv('csv-P30AG04428-set.csv')
#publications_list

# %%
dataframe = pd.DataFrame(publications_list)

# %%
dataframe

# %%
df = pd.DataFrame(publications_list, columns=['PMID', 'PMCID', 'Publication_Year', "Journal"])

# %%
df.columns

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = dataframe.Publication_Year
y = dataframe.Journal

# %%
plt.scatter(x, y)
plt.title('Journals We Published To Over the Years')

# %%
plt.hist(y)
plt.title('Journals Histogram')

# %%
plt.bar(x, height=y)
plt.title('Journals over the Years')

# %%
x = dataframe.Publication_Year
z = dataframe.First_Author

plt.scatter(x, z)
plt.title('First Authors Who Published To Over the Years')

# %%
x = dataframe.Publication_Year
t = dataframe.Title

plt.scatter(x, t)
plt.title('Articles Published To Over the Years')
